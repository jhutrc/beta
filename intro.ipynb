# %% [markdown]
# # Fena
#
# ```{margin} Abstract
# ```unix
#
# In the modern era of medical research, collaboration, transparency, and open access to knowledge are paramount. Embracing the "we are all in the same boat" philosophy, our community, ranging from high school students to faculty, staff, analysts, and collaborators, has adopted Fena, an innovative static site generator. This Luganda term, idiomatic for our collective engagement, epitomizes our unified approach to challenges like truth, rigor, error, and sloppiness, while also acknowledging the daily grind of academia.
#
# Fena is our platform to sail in the same boat across various projects involving git, code, manuscripts, and the utilization of skills like Python, AI tools (ChatGPT and GitHub Copilot), R, Stata, and more. It equips us to navigate the complex terrains of numeracy, such as point and interval estimates, and literacy, in alignment with the open-science movement.
#
# Through self-publication, web apps with individualized risk scores for patients, peer-reviewed publications, and grant applications, Fena fosters a sense of shared responsibility and ambition. It's not just a tool but a symbol of our unified pursuit of medical progress, emphasizing that whether in skill development, challenging tasks, or innovative projects, we are all steering in the same direction. This unique embrace of Fena promises to revolutionize the way we share research, break down barriers to access, and accelerate the pace of medical advancements in a world where, indeed, we are all in the same boat.
#
# ```
#
# *Yaffe ffena[.](https://www.youtube.com/watch?v=4GuMQXRl0_0)*
# *我们同舟共济*
# *نحن جميعاً معاً*
# *כולנו בזה ביחד*
# *Todos estamos en esto juntos*
# *Nous sommes tous dans le même bateau*
# *Wir sitzen alle im selben Boot*
# *Siamo tutti nella stessa barca*
# *Estamos todos juntos nisso*
# *We zitten hier allemaal samen in*
# *Мы все в этом вместе*
# *हम सब इसमें साथ हैं*
# *ما همه در این هستیم به همراه*
# *これは私たちみんなのものです*
# *Sisi sote tuko pamoja katika hili*
# *Sisonke kule*
# *Awa gbogbo ni lori e pelu*
# *Anyị nile nọ n'ime ya*
# *우리는 모두 함께 이것에 있습니다*
# *Olemme kaikki tässä yhdessä*
# *እኛ ሁሉም በዚህ ተባበርንዋል*
# *Hinqabu fi hinqabu jechuun*
# *ምንም ነገርና እኛ በእኛ*
# *આપણે બધા આમાં જ છીએ*
#
#
# #
#
# ```{margin}
# ```{figure} https://github.com/jhutrc/beta/blob/main/act_0/act_0_2/act_0_2_1/hero.jpg?raw=true
# ```
#
# #
#
# #
#
# # You
#
# [High School Students](./act_0/act_0_0/act_0_0_0/act_0_0_0_1.ipynb)
# [Undergraduates](./act_0/act_0_0/act_0_0_1/act_0_0_1_1.ipynb)
# [Graduate Students](./act_0/act_0_0/act_0_0_2/act_0_0_2_1.ipynb)
# [Medical Students](./act_0/act_0_0/act_0_0_3/act_0_0_3_1.ipynb)
# [Residents](./act_0/act_0_0/act_0_0_4/act_0_0_4_1.ipynb)
# [Fellows](./act_0/act_0_0/act_0_0_5/act_0_0_5_1.ipynb)
# [Graduates](./act_0/act_0_0/act_0_0_6/act_0_0_6_1.ipynb)
# [Faculty](./act_0/act_0_0/act_0_0_7/act_0_0_7_1.ipynb)
# [Analysts](./act_0/act_0_0/act_0_0_8/act_0_0_8_1.ipynb)
# [Staff](./act_0/act_0_0/act_0_0_9/act_0_0_9_1.ipynb)
# [Collaborators](./act_0/act_0_1/act_0_1_0/act_0_1_0_1.ipynb)
#
#
# #
#
# #
#
# # Intro

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Set seed for layout
seed = 2

# Directory structure
structure = {
    "Skills": ["Literacy", "Project", "Numeracy", "You", "Challenges"],
    "Estimate": ["Interval", "R01", "K24", "U01"],
    "Literacy": ["Open-Science", "Self-Publish", "Peer-Reviewed", "Grants", "Proposals"],
    "Numeracy": ["Python", "AI", "R", "Stata", "Estimate"],
    "AI": ["ChatGPT", "Co-Pilot"],
    "Project": ["Manuscript", "Code", "Git"],
    "Point": ["Nonparametric", "Semiparametric", "Parametric", "Simulation", "Uses/Abuses"],
    "Estimate": ["Point", "Interval"],
    "Interval": ["Oneway", "Twoway", "Multivariable", "Hierarchical", "Clinical", "Public"],
    "You": ["High School Students", "Undergraduates", "Graduate Students", "Medical Students", "Residents", "Fellows", "Faculty", "Analysts", "Staff", "Collaborators", "Graduates"],
    "Challenges": ["Truth", "Rigor", "Error", "Sloppiness", "Fraud", "Learning"],
}

# Gentle colors for children
child_colors = ["lightgreen", "lightpink", "lightyellow",
    'lavender', 'lightcoral', 'honeydew', 'azure','lightblue', 
]

# 'lightsteelblue', 'lightgray', 'mintcream','mintcream', 'azure', 'linen', 'aliceblue', 'lemonchiffon', 'mistyrose'

# List of nodes to color light blue
light_blue_nodes = ["Literacy", "Numeracy", "You", "Project", "Challenges"]

G = nx.Graph()
node_colors = {}


# Function to capitalize the first letter of each word
def capitalize_name(name):
    return ' '.join(word.capitalize() for word in name.split(" "))

# Assign colors to nodes
for i, (parent, children) in enumerate(structure.items()):
    parent_name = capitalize_name(parent.replace("_", " "))
    G.add_node(parent_name)
    
    # Set the color for Skills
    if parent_name == "Skills":
        node_colors[parent_name] = 'lightgray'
    else:
        node_colors[parent_name] = child_colors[i % len(child_colors)]
        
    for child in children:
        child_name = capitalize_name(child.replace("_", " "))
        G.add_edge(parent_name, child_name)
        if child_name in light_blue_nodes:
            node_colors[child_name] = 'lightblue'
        else:
            node_colors[child_name] = child_colors[(i + 6) % len(child_colors)]  # You can customize the logic here to assign colors


colors = [node_colors[node] for node in G.nodes()]

# Set figure size
plt.figure(figsize=(30, 30))

# Draw the graph
pos = nx.spring_layout(G, scale=30, seed=seed)
nx.draw_networkx_nodes(G, pos, node_size=10000, node_color=colors, edgecolors='black')  # Boundary color set here
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos, font_size=20)
plt.show()

# %% [markdown]
# <span style="font-size: 1.8em; font-weight: bold; position: relative; top: 0.3em;">L</span>ife is an unending series of challenges. Each day, we are met with tasks that test our skills, our intellect, our mettle. Since the dawn of time, humanity has sought tools and techniques to gain the upper hand, to transform daunting challenges into opportunities for growth and triumph.
#
# In the modern era, where the pace of change is relentless, where the demands of clinical research and the pursuit of medical excellence never wane, the need for such tools is more pressing than ever.
#
# Welcome to Fena.
#
# Fena isn't just another tool; it's a symbol of our shared ambition. It's a vessel that carries us in unison across the complex seas of numeracy, literacy, and innovation. With its robust framework and adaptable problem-solving techniques, Fena equips high school students, undergraduates, faculty, analysts, and collaborators with the skills necessary to navigate the intricate terrains of clinical research.
#
# Our graph, gently colored and thoughtfully structured, represents the interconnectedness of our community and the multifaceted nature of our work. It's a visual testament to our collective strength, our unified pursuit of truth, rigor, and medical progress.
#
# With Fena, we sail in the same boat across various projects involving git, code, manuscripts, and the utilization of skills like Python, AI tools, R, and Stata. It's more than a platform; it's our commitment to each other, our promise to strive, to explore, to innovate, to overcome.
#
# We are all steering in the same direction, and with Fena, we are always in the zone, always in flow. Together, we will revolutionize the way we share research, break down barriers, and accelerate the pace of medical advancements.
#
# Join us, and be a part of the journey. Be a part of Fena.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data for the skill and challenge levels
skill_levels = np.linspace(0, 10, 100)
challenge_levels = np.linspace(0, 10, 100)

# Define the flow channel boundaries
flow_channel = skill_levels

# Adjust the phase and amplitude of the sinusoid wave
phase = np.pi / 16
amplitude = 1.5
sinusoid = flow_channel + np.sin(skill_levels + phase) * amplitude

# Define the yellow zone boundaries, making it wider
yellow_zone_low = skill_levels - 1.5  # Adjust this value to make the yellow zone wider or narrower
yellow_zone_high = skill_levels + 1.5 # Adjust this value to make the yellow zone wider or narrower

# Plotting
plt.figure(figsize=(15, 10))

# Plot the anxiety and boredom areas
plt.fill_between(skill_levels, yellow_zone_high, 10, color='orangered', alpha=0.3, label='Place/Identification', interpolate=True)
plt.fill_between(skill_levels, 0, yellow_zone_low, color='lime', alpha=0.3, label='Time/Revelation', interpolate=True)
plt.fill_between(skill_levels, yellow_zone_low, yellow_zone_high, color='yellow', alpha=0.3, label='Agent/Evolution', interpolate=True)

# Plot the sinusoid function with the diagonal as its axis
plt.plot(skill_levels, sinusoid, color='purple', linestyle='-')

# Add arrowhead to the sinusoid line
plt.arrow(skill_levels[-2], sinusoid[-2], skill_levels[-1] - skill_levels[-2], sinusoid[-1] - sinusoid[-2],
          color='purple', length_includes_head=True, head_width=0.15, head_length=0.3)

# Set plot labels and title
plt.xlabel('Skill-level', fontsize=18)
plt.ylabel('Challenge-level', rotation='vertical', fontsize=18)

# Set plot limits and grid
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.grid(True)

# Set tick labels
tick_labels = ['0', '2', '4', '6', '8', '10']
plt.xticks(np.linspace(0, 10, 6), tick_labels)
plt.yticks(np.linspace(0, 10, 6), tick_labels)

# Add text annotations to label the areas without shaded background
plt.text(1, 6, 'Anxious', color='black', ha='center', va='center', fontsize=18)
plt.text(4.5, 4.7, 'Flow', color='black', ha='center', va='center', fontsize=18)
plt.text(8, 3, 'Bored', color='black', ha='center', va='center', fontsize=18)

# Display the plot
plt.show()

# %% [markdown]
# `Fena`, the platform in focus, serves as a groundbreaking static site generator that fosters collaboration and knowledge sharing within the medical research arena. It embodies the "we are all in the same boat" philosophy, engaging a wide spectrum of individuals from high school students to seasoned professionals in faculty, staff, and collaboration roles.
#
# The platform's key objective is to facilitate "flow," a state of optimal performance where challenges are perfectly balanced with skills. Through Fena, participants are equipped to navigate the intricate landscapes of numeracy and literacy, embracing various tools such as Python, AI tools (ChatGPT and GitHub Copilot), R, Stata, and more. The goal is to attain a seamless workflow that synchronizes skill development, challenging tasks, and innovative projects.
#
# The accompanying visualization symbolizes this journey towards flow. It portrays the balance of challenge and skill levels, capturing areas of anxiety, flow (the optimal zone), and boredom. This diagram serves as a metaphorical map, guiding the community in their collective pursuit of clinical research excellence.
#
# In a nutshell, Fena is not merely a tool but a beacon for collaborative medical research. It prioritizes the pursuit of "flow," empowering its diverse community with adaptable problem-solving skills, and facilitating a streamlined workflow that promises to redefine accessibility and accelerate the pace of medical innovation.

# %% [markdown]
# ```{figure} https://github.com/jhutrc/beta/blob/main/act_0/act_0_2/act_0_2_1/jhu.gif?raw=true
# :name: github_tut
#
# :caption: This image of jubilant graduates symbolizes the triumphant achievement of a significant milestone, reflecting the continuous growth and advancement in skills that Fena promotes.
#
# Check out this [Github tutorial](https://youtu.be/w3jLJU7DT5E) to get started 🎉📚
#
# ```{margin}
# ```{note}
# Fena is a resource open to a wide range of individuals, transcending institutional boundaries.
