# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_hub_and_spoke(num_spokes):
    # Create a directed graph
    G = nx.DiGraph()

    # Add the hub node (changed "Hub" to "Git")
    G.add_node("Git", node_color="skyblue", node_size=50000)

    # Define colors for spokes
    spoke_colors = ["green", "lime", "yellow", "orange", "red", "maroon", "purple", "blue", "cyan", "pink", "brown"]

    # Add the spoke nodes and edges connecting them to the hub
    spoke_names = [
        "High School Students",
        "Undergraduates",
        "Graduate Students",
        "Medical Students",
        "Residents",
        "Fellows",
        "Faculty",
        "Analysts",
        "Staff",
        "Collaborators",
        "Graduates"
    ]
    for i in range(num_spokes):
        spoke_name = spoke_names[i]
        G.add_node(spoke_name, node_color=spoke_colors[i], node_size=50000)
        G.add_edge(spoke_name, "Git")  # Connect spokes to "Git"

    # Set the positions of nodes for better visualization (circular layout)
    pos = nx.circular_layout(G)

    # Get node attributes for visualization
    node_colors = [G.nodes[n]['node_color'] for n in G.nodes()]
    node_sizes = [G.nodes[n]['node_size'] for n in G.nodes()]

    # Draw the graph with even bigger arrows and arrowheads (arrowsize and connectionstyle parameters)
    plt.figure(figsize=(15, 10))
    nx.draw(G, pos, with_labels=True, node_color=node_colors, node_size=node_sizes, font_size=20, font_weight='bold', arrowsize=40, connectionstyle="arc3,rad=-0.3")
    plt.title("", fontsize=20)
    plt.axis('off')
    plt.show()

# Example usage:
draw_hub_and_spoke(11)

# %% [markdown]
# <span style="color: orange;">Medical Students</span>
#
# 1. [Andrew Arking](medical_students_1/medical_students_1.ipynb)
# 2. Emily Kim
# 3. Muhammad Rahman
# 4. Maya Patel
# 5. Carlos Ramirez
# 6. Aisha Khan
# 7. Benjamin Nguyễn
# 8. Olivia Lopez
# 9. James Martinez
# 10. Fatima Ali
# 11. Alexander Gómez
# 12. Priya Desai
# 13. David Okafor
# 14. Sofia Almeida
# 15. Daniel Kimani
# 16. Isabella Navarro
# 17. Ethan Chen
# 18. Chloe Ahmed
# 19. Joseph Amara
# 20. Amelia Nwosu
# 21. Samuel Nascimento
# 22. Evelyn Gupta
# 23. David Nguyen
# 24. Harper Lee
# 25. Christopher Choudhury
# 26. Abigail Kaur
# 27. Matthew Hernandez
# 28. Harper Kumar
# 29. Jayden García
# 30. Sofia Silva
# 31. Daniel Wong

# %% [markdown]
# i want code to produce a circle with a radius of 5
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.linspace(-5, 5, 100)
# y = np.sqrt(25 - x**2)
#
# plt.plot(x, y, 'b')
# plt.plot(x, -y, 'b')
# plt.axis('equal')
# plt.show()
# ```
#
# ```javascript
# var x = 5;
# var y = 6;
# var z = x + y;
#
# ```

# %%
import numpy as np  
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = np.sqrt(25 - x**2)

plt.plot(x, y, 'b')
plt.plot(x, -y, 'b')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt

circle_radius = 5

fig, ax = plt.subplots()  # Create a new figure with a subplot
circle = plt.Circle((0, 0), circle_radius, fill = False)  # Create the circle

ax.add_artist(circle)  # Add the circle to the axes
ax.set_aspect('equal')  # Ensure the circle is circular (not elliptical)

# Set the limits of the plot to the circle's extent
ax.set_xlim(-circle_radius, circle_radius)
ax.set_ylim(-circle_radius, circle_radius)

plt.show()  # Display the plot

# %% [markdown]
# Let me post this online! I'm sure it will be useful to someone else.
