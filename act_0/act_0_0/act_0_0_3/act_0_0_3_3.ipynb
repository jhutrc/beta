# %% [markdown]
# 1. **Introduction**:
#    - [Project](https://github.com/jhurepos/projectalpha/blob/main/seasons_projectalpha_0/seasons.docx) led by Andrew, studying seasonality of kidney donation in the U.S.
#    - Examining implications and reversal of donor decline.
#
# 2. **Background**:
#    - Observed decline in kidney donors.
#    - No identified factors [explaining/controling](./../../../act_1/act_1_0/act_1_0_0/act_1_0_0_1.ipynb) the decline.
#
# 3. **Objectives**:
#    - Investigate seasonality (hierarchical data) and factors (mixed effects) contributing to it in kidney donation.
#
# 4. **Methodology**:
#    - [Revamp entire analysis](./act_0_0_3_4.ipynb) using `group-level and individual-level predictors`.
#
# 6. **Results**:
#    - Identification of summer surge in donations from 1987-2023. [See](./act_0_0_3_4.ipynb) back-of-the-envelope calculations.
#
# 7. **Discussion**:
#    - Emphasizing significance of seasonal variation and potential implications.
#
# 8. **Current Status**:
#    - Andrew made his first direct commit on 8/31, focusing on the figures.
#    - He did not update using immediately preceding version, so the commit history is not accurate.
#    - Problem might have come from Abi's misleading commit message on 8/30 "This is just for demo purposes".
#    - The only demo was in the title but substantive edits were made to the intro, methods, results, and discussion
#    - **Let's discuss this in our next meeting**.
#
# 9. **Next Steps**:
#    - Wait for comments from Fawaz before we schedule the next meeting.
#    - Encourage Fawaz to make direct commits to the manuscript!!
#
# 10. **Remark**:
#    - Andrew will have to update his R script to accomodate issues raised in the [revamped analysis](./act_0_0_3_4.ipynb).
#    - [Chapter 2](./../../../act_1/act_1_0/act_1_0_0/act_1_0_0_1.ipynb) of this platform will be helpful in understanding the new approach.
#
# 11. **Version history**:
#    - Please don't be afraid of making extensive comments to a version or even a mistake.
#    - We can always revert to a previous version if needed :)
#
# ---
#
# #
#
# # Current version has addressed these issues; but perform a checklist during the next meeting
#
# <span style="font-size: 1.2em; font-weight: bold; position: relative; top: 0.0em;">Subject: Revisions and Feedback on Seasons.docx Manuscript</span>
#
# Dear Andrew and Abi,
#
# I hope this message finds you well. First, let me congratulate Andrew on the significant improvements made to the manuscript so far. The revisions have brought it a long way. However, I believe we should further refine the manuscript by adjusting some figures and emphasizing our key findings more effectively.
#
# <span style="font-size: 1.2em; font-weight: bold; position: relative; top: 0.0em;">Background and Take-Home Message:</span>
#
# **Rationale:** The decline in living kidney donors over the past two decades has been notably due to a decrease in biologically related donors. Our study aims to identify modifiable factors to reverse this trend.
#
# **Conclusion:** Our findings indicate that biologically related donors from lower and middle income tiers, based on Zip-code, show an increase in donations during the summer. We advocate for targeted programs that can help these groups expand donations in the summer while also overcoming barriers in other seasons.
#
# <span style="font-size: 1.2em; font-weight: bold; position: relative; top: 0.0em;">General Points:</span>
#
# - Please update the study time window to 1990-2019 in all figures, tables, and texts.
# - Figure 2 is particularly compelling as it highlights the summer peak in donations across the 1990s, 2000s, and 2010s.
#
#
# <span style="font-size: 1.2em; font-weight: bold; position: relative; top: 0.0em;">Minor Points:</span>
#
# 1. **Figure 1:** Limit the time window to 1990-2019.
#
# 2. **Figure 2:**
#     - Thin the lines slightly for better readability.
#     - Adjust Y-axis label to "U.S. Monthly Living Kidney Donation" (and clarify in a footnote that this reflects the median).
#
# 3. **Figure 3:**
#     - For the legend, use "lowest, middle, highest tertile" instead of 1st, 2nd, and 3rd.
#     - Y-axis label should read "Donation Incidence Rate Ratio."
#
# <span style="font-size: 1.2em; font-weight: bold; position: relative; top: 0.0em;">Major Points:</span>
#
# 1. **Figure 2 Revisions:**
#     - Keep the Y-axis the same.
#     - Adjust the X-axis to span from 1990 to 2019.
#     - Change the trend category from "Era" to "Season."
#
# 2. **Figure 3 Revisions:**
#     - Keep the Y-axis the same.
#     - Adjust the X-axis to reflect seasons.
#     - Stratify this revised Figure 3 by race/ethnicity:
#         - Among White
#         - Among Black
#         - Among Asian
#         - Among Hispanic
#         - Exclude other races from this figure for consistency with previous studies but mention them in Table 1 under "Others."
#
# I am available to meet for further discussions this coming week, as needed. For urgent matters, please feel free to text me at 720-401-9364.
#
# Together, we can make impactful contributions to this field.
#
# Best regards,
# Fawaz
#
# ---
#
#
# # 1
#
# Subject: Summary of Project Contributions and Upcoming Meeting Agenda
#
# Dear Team,
#
# I hope this message finds you well. I wanted to summarize the contributions made so far to our ongoing project and outline the agenda for our upcoming meeting.
#
# 1. Andrew has made substantive edits focusing solely on the figures, without altering the main body of the text.
#
# 2. Abi has provided valuable comments and suggestions, covering both Andrew's edits to the figures and the original text.
#
# 3. Fawaz has offered extensive insights via email, though these have not yet been applied directly to the manuscript.
#
# **Upcoming Meeting Agenda:**
#
# - Brief Introduction to GitHub Commits
#    - Familiarize everyone with the use of GitHub for version control. Adopting this practice will make our workflow more efficient, eliminating the need for individual update summaries like this one moving forward.
# - Discuss of Edits and suggestions from Andrew, Abi, and Fawaz
#    - This session will focus on the substantive edits and suggestions made by Andrew, Abi, and Fawaz. We will discuss these in detail and decide how to incorporate them into the manuscript.
# - Commit to the next steps for the project
#    - We will discuss the timeline for completing the the edits and submitting the manuscript to coautahors for review.
#
# Looking forward to our collaborative progress!
#
# Best regards,
#
# Abi
