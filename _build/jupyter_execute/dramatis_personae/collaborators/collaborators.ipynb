# %% [markdown]
# <span style="color: pink;">Collaborators</span>
#
# 1. [Fawaz Al Ammary](fawaz_al_ammary/fawaz_al_ammary.ipynb)
# 2. Sophia Turner
# 3. Ethan Cruz
# 4. Hannah Murphy
# 5. Caleb Reyes
# 6. Zoe Harper
# 7. Gabriel Ortega
# 8. Avery Rhodes
