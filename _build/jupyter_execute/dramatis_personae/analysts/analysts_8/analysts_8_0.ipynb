# %% [markdown]
# # Install required packages for creating a Jupyter-book in Windows 10 using a Linux shell.
#
# ## 1. Install Windows Subsystem for Linux (WSL)
#
# - Open the Microsoft Store
# - Search for "Linux"
# - Click on "Get" for "Ubuntu 20.04 LTS"
# - Click on "Launch"
# - Create a username and password
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get update
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get upgrade
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get install python3-pip
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get install git
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get install python3-venv
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# sudo apt-get install python3.8-venv
# ```
#
# ## 1.1. Create a virtual environment
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# python3.8 -m venv myvenv
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# source myvenv/bin/activate
# ```
#
# ## 1.2. Install Jupyter-book
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# pip install -U jupyter-book
# ```
#
# ## 1.3. Create a Jupyter-book
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
#
# jupyter-book create mybook
# ```
#
# ## 1.4. Install Jupyter-book dependencies
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# cd mybook
# ```
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ## 1.5. Build the Jupyter-book
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
# jupyter-book build mybook
# ```
#
# ## 1.6. Serve the Jupyter-book
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
#
# jupyter-book serve mybook
# ```
#
# ## 1.7. Open the Jupyter-book
#
# - Open a browser
#
# - Type the following URL in the browser:
#
# ```bash
#
# http://localhost:4000/
# ```
#
# ## 1.8. Deactivate the virtual environment
#
# - Type the following command in the Ubuntu terminal:
#
# ```bash
#
# deactivate
# ```
#
# ## 1.9. Let's leave these other options if they better suit you:
#
# - Cygwin
# - Anaconda
# - Docker
# - VirtualBox
# - Vagrant
# - Miniconda
# - Chocolatey
# - [Conda](analysts_8_1.ipynb)
# - Pip
# - Pipenv
# - Poetry
#
# # 2. Install required packages for creating a Jupyter-book on a Mac.
#
# ## 0. Install Homebrew
#
# - Open a terminal
#
# - Type the following command in the terminal:
#
# ```bash
#
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# ```
#
# ## 2.1. Install Python
#
# - Type the following command in the terminal:
#
# ```bash
#
# brew install python
# ```
#
# ## 2.2 Install Jupyter-book
#
# - Type the following command in the terminal:
#
# ```bash
#
# pip install -U jupyter-book
# ```
#
# ## 2.3. Create a Jupyter-book
#
# - Type the following command in the terminal:
#
# ```bash
#
# jupyter-book create mybook
# ```
#
# ## 2.4. Install Jupyter-book dependencies
#
# - Type the following command in the terminal:
#
# ```bash
#
# cd mybook
# ```
#
# - Type the following command in the terminal:
#
# ```bash
#
# pip install -r requirements.txt
# ```
#
# ## 2.5. Build the Jupyter-book
#
# - Type the following command in the terminal:
#
# ```bash
#
# jupyter-book build mybook
# ```
#
# ## 2.6. Serve the Jupyter-book
#
# - Type the following command in the terminal:
#
# ```bash
#
# jupyter-book serve mybook
# ```
#
# ## 2.7. Open the Jupyter-book
#
# - Open a browser
#
# - Type the following URL in the browser:
#
# ```bash
#
# http://localhost:4000/
# ```
