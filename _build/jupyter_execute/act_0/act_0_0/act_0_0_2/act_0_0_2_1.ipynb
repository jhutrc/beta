# %%
import networkx as nx
import matplotlib.pyplot as plt

# Set seed for layout
seed = 2

# Directory structure
structure = {
    "Skills": ["Literacy", "Project", "Numeracy", "Workflow", "Challenges"],
    "Estimate": ["Interval", "R01", "K24", "U01"],
    "Literacy": ["Open-Science", "Self-Publish", "Peer-Reviewed", "Grants", "Proposals"],
    "Numeracy": ["Python", "AI", "R", "Stata", "Estimate"],
    "AI": ["ChatGPT", "Co-Pilot"],
    "Project": ["Manuscript", "Code", "Git"],
    "Point": ["Nonparametric", "Semiparametric", "Parametric", "Simulation", "Uses/Abuses"],
    "Estimate": ["Point", "Interval"],
    "Interval": ["Oneway", "Twoway", "Multivariable", "Hierarchical", "Clinical", "Public"],
    "Workflow": ["High School Students", "Undergraduates", "Graduate Students", "Medical Students", "Residents", "Fellows", "Faculty", "Analysts", "Staff", "Collaborators", "Graduates"],
    "Challenges": ["Truth", "Rigor", "Error", "Sloppiness", "Fraud", "Learning"],
}

# Gentle colors for children
child_colors = ["lightgreen", "lightpink", "lightyellow",
    'lavender', 'lightcoral', 'honeydew', 'azure','lightblue', 
]

# 'lightsteelblue', 'lightgray', 'mintcream','mintcream', 'azure', 'linen', 'aliceblue', 'lemonchiffon', 'mistyrose'

# List of nodes to color light blue
light_blue_nodes = ["Literacy", "Numeracy", "You", "Project", "Challenges"]

G = nx.Graph()
node_colors = {}


# Function to capitalize the first letter of each word
def capitalize_name(name):
    return ' '.join(word.capitalize() for word in name.split(" "))

# Assign colors to nodes
for i, (parent, children) in enumerate(structure.items()):
    parent_name = capitalize_name(parent.replace("_", " "))
    G.add_node(parent_name)
    
    # Set the color for Skills
    if parent_name == "Skills":
        node_colors[parent_name] = 'lightgray'
    else:
        node_colors[parent_name] = child_colors[i % len(child_colors)]
        
    for child in children:
        child_name = capitalize_name(child.replace("_", " "))
        G.add_edge(parent_name, child_name)
        if child_name in light_blue_nodes:
            node_colors[child_name] = 'lightblue'
        else:
            node_colors[child_name] = child_colors[(i + 6) % len(child_colors)]  # You can customize the logic here to assign colors


colors = [node_colors[node] for node in G.nodes()]

# Set figure size
plt.figure(figsize=(30, 30))

# Draw the graph
pos = nx.spring_layout(G, scale=30, seed=seed)
nx.draw_networkx_nodes(G, pos, node_size=10000, node_color=colors, edgecolors='black')  # Boundary color set here
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos, font_size=20)
plt.show()

# %% [markdown]
# <span style="color: yellow;">Graduate Students</span>
#
# 1. Aaliyah Johnson
# 2. Abdiel Al-Hussein
# 3. Aditya Patel
# 4. Aisha Obi
# 5. Akiko Tanaka
# 6. Alejandro Vasquez
# 7. Alina Kuznetsov
# 8. Amani El-Ghoul
# 9. Amar Bhatia
# 10. Anaya Naidu
# 11. André Fontaine
# 12. Angelica Rodriguez
# 13. Anika Singh
# 14. Ansel Kim
# 15. Antonio Lopez
# 16. Arjun Reddy
# 17. Asha Nkosi
# 18. Bahar Safarova
# 19. Beckett O'Donnell
# 20. Binh Nguyen
# 21. Bodhi Srinivasan
# 22. Brielle Watson
# 23. Caitlin O'Reilly
# 24. Carlos Bermudez
# 25. Chandra Joshi
# 26. Chike Okonkwo
# 27. Dae-Ho Park
# 28. Dahlia El-Masri
# 29. Darius Washington
# 30. Devika Pillai
# 31. Diya Sharma
# 32. Eduardo Mendoza
# 33. Efe Ozturk
# 34. Elise Lambert
# 35. Emani Abubakar
# 36. Emeka Okafor
# 37. Enrique Pena
# 38. Esmeralda Garcia
# 39. Faiza Hassan
# 40. Farid Al-Rashid
# 41. Fatima Zahid
# 42. Felix Schmidt
# 43. Gabriela Alvarez
# 44. Gaia Romano
# 45. Giancarlo D'Amico
# 46. Hakim El-Amin
# 47. Hana Joo
# 48. Hiroshi Yamamoto
# 49. Ibrahim Ahmed
# 50. Imani Turner
# 51. Indira Varma
# 52. Ioannis Angelopoulos
# 53. Isabella Moreno
# 54. Jabari Nkomo
# 55. Jada Thompson
# 56. Jamil Said
# 57. Janelle Martinez
# 58. Javier Cortez
# 59. Jia Li
# 60. Joaquim Barros
# 61. Kamala Rajan
# 62. Karim Fayed
# 63. Keisha Campbell
# 64. Khaled Assaf
# 65. Kiara Smith
# 66. Kofi Mensah
# 67. Laila Khaled
# 68. Leticia Barbosa
# 69. Li Wei Chen
# 70. Luisa Rios
# 71. Madhavi Latha
# 72. Mahir Al-Aziz
# 73. Malachi Peters
# 74. Malika Benoit
# 75. Manuel Ortega
# 76. Mariam Saidi
# 77. Marius Popescu
# 78. Mei Huang
# 79. Mikael Johansson
# 80. Miriam Goldstein
# 81. Mohammed Al-Faraj
# 82. Monique Dubois
# 83. Nadia Rahman
# 84. Nahla Tariq
# 85. Nam Phan
# 86. Naomi Wanjiru
# 87. Naveen Kumar
# 88. Neelam Bhatt
# 89. Ngoc Dao
# 90. Nicolás Herrera
# 91. Nour Salim
# 92. Olga Petrov
# 93. Omari Jones
# 94. Padma Rangan
# 95. Paolo Conti
# 96. Parvati Nayar
# 97. Pia Lombardi
# 98. Priyanka Chatterjee
# 99. Qasim Al-Zahra
# 100. Quentin Leroux
# 101. Raheem Abdul
# 102. Rajan Iyer
# 103. Reuben Goldberg
# 104. Riko Suzuki
# 105. Roshan DeSilva
# 106. Sabrina El-Amari
# 107. Sade Olufemi
# 108. Sahil Mehta
# 109. Sanaa Mostafa
# 110. Sang Min
# 111. Sanjit Roy
# 112. Sergio Ruiz
# 113. Shanice King
# 114. Shanti Desai
# 115. Shiori Nakamura
# 116. Shreya Banerjee
# 117. Simran Kaur
# 118. Sofia Dominguez
# 119. Solange Fontes
# 120. Sunil Verma
# 121. Taiwo Adebowale
# 122. Takumi Watanabe
# 123. Talia Cohen
# 124. Tamika Grant
# 125. Tao Wang
# 126. Tariq Jamal
# 127. Tendai Moyo
# 128. Thanh Vu
# 129. Thiago Ribeiro
# 130. Uzoma Eze
# 131. Valentina Mironov
# 132. Van Le
# 133. Victoria Ng
# 134. Vivek Deshmukh
# 135. Ximena Delgado
# 136. Xiu Ying Zhou
# 137. Yael Steinberg
# 138. Yara Nasser
# 139. Yasmeen Al-Hariri
# 140. Youssef Boutros
# 141. Zahra Khouri
# 142. Zainab Al-Salem
# 143. Zara Sheikh
# 144. Zenaida Maldonado
# 145. Zephyr Lachapelle
# 146. Zhou Wei
# 147. Zuri Njeri
# 148. Abdoulaye Diop
# 149. Aiden McKenna
# 150. Alonzo Morales
# 151. Amrita Bains
# 152. Asif Qureshi
# 153. Beatriz Soto
# 154. Boris Ivanov
# 155. Caden Fitzgerald
# 156. Camille Dupont
# 157. Daquan Brooks
# 158. Deepa Raghavan
# 159. Desiree Villanueva
# 160. Dwight Robinson
# 161. Elif Yilmaz
# 162. Emir Kaya
# 163. Fatou Sow
# 164. Flavia Costa
# 165. Gaurav Bhasin
# 166. Hafsa Farooq
# 167. Hassan Rizvi
# 168. Ikram Elahi
# 169. Isidro Valdez
# 170. Jaxon Price
# 171. Jerome Baptiste
# 172. Katarina Novak
# 173. Keegan O'Sullivan
# 174. Lani Kahale
# 175. Luciana Ferreira
# 176. Makena Kariuki
# 177. Marisol Pena
# 178. Naima Salah
# 179. Omarion McLeod
# 180. Parisa Farsi
# 181. Pooja Gopal
# 182. Quinlan O'Connor
# 183. Rafaela Silva
# 184. Ramon Fernandez
# 185. Saniyah Ali
# 186. Seamus Gallagher
# 187. Shayan Rizwan
# 188. Takashi Taniguchi
# 189. Uday Joshi
# 190. Velma Mwangi
# 191. Wendell Harris
# 192. Xander Grey
# 193. Yanira Cordero
# 194. Yesenia Guzman
# 195. Zalika Diarra
# 196. Alejandro Mora
# 197. Bianca Rosales
# 198. Carlito Espinoza
# 199. Damaris Vega
# 200. Eleazar Gomez
# 201. Francesca Rossi
# 202. Guadalupe Torres
# 203. Horacio Gutierrez
# 204. Ines Silva
# 205. Joaquin Mendez
# 206. Karla Vargas
# 207. Lourdes Guerrero
# 208. Mauricio Navarro
# 209. Noemi Herrera
# 210. Osvaldo Rojas
# 211. Paloma Blanco
# 212. Reynaldo Chavez
# 213. Silvia Marquez
# 214. Trinidad Luna
# 215. Uriel Delgado
# 216. Violeta Mendoza
# 217. Wilmer Calderon
# 218. Yolanda Ortega
# 219. Zacarias Ramos
# 220. Aarav Nair
# 221. Beatrice Oluoch
# 222. Chinaza Okoye
# 223. Drishti Patel
# 224. Esteban Mora
# 225. Faizan Khan
# 226. Ghazala Rehman
# 227. Hina Yusuf
# 228. Idris Kone
# 229. Jasleen Bhullar
# 230. Khalil Sayed
# 231. Lakshmi Raghav
# 232. Mohammed Ismail
# 233. Nishaan Ahuja
# 234. Opeyemi Akinwande
# 235. Pranav Mathur
# 236. Qamar Zaidi
# 237. Rajan Luthra
# 238. Sabeen Rizvi
# 239. Talha Javed
# 240. Uma Iyer
# 241. Vasudha Raghavan
# 242. Wajahat Mirza
# 243. Xian Wu
# 244. Yashika Mehta
# 245. Zeeshan Aslam
# 246. Abeer Qureshi
# 247. Bilal Siddiqui
# 248. Chandni Verma
# 249. Danish Haq
# 250. Eshita Kapoor
# 251. Faisal Nadeem
# 252. Geetika Joshi
# 253. Hamza Malik
# 254. Ishaan Oberoi
# 255. Javeria Khawaja
# 256. Kunal Bajaj
# 257. Lubna Firdous
# 258. Muzammil Ali
# 259. Naina Thakur
# 260. Owais Shah
# 261. Parul Goyal
# 262. Qudsia Aslam
# 263. Raghav Mehra
# 264. Sakina Jaffery
# 265. Taher Momin
# 266. Uzma Farooq
# 267. Vishal Suri
# 268. Wasiq Iqbal
# 269. Xiu Ling
# 270. Yusra Khan
# 271. Zulfiqar Ahmed
# 272. Aaditya Rajan
# 273. Bhavna Malhotra
# 274. Charu Sethi
# 275. Dipen Patel
# 276. Eman Sheikh
# 277. Farhan Tariq
# 278. Gitanjali Rao
# 279. Haroon Rashid
# 280. Ishrat Shaikh
# 281. Jyoti Rana
# 282. Kiran Deshmukh
# 283. Lata Mangeshkar
